# %%
class ArrayList:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
        
    def swap(self, i, j):
        tmp = self.inArray[i]
        self.inArray[i] = self.inArray[j]
        self.inArray[j] = tmp
    
    def get(self, i):
        return self.inArray[i]

    def set(self, i, e):
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()     # resize array if reached capacity

    def insert(self, i, e):
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()     # resize array if reached capacity

    def remove(self, i):
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val
    
    def __str__(self):
        return str(self.inArray[:self.count])

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray

class Heap:
    def __init__(self):
        self.inList = ArrayList()
        self.size = 0
        
    def __str__(self):
        return str(self.inList)
        
    def add(self, d):
        self.inList.append(d)
        pos = self.size
        self.size += 1
        while pos > 0 and self.inList.get(pos) > self.inList.get((pos-1)//2):
            self.inList.swap(pos,(pos-1)//2)
            pos = (pos-1)//2
        
    def heapify(self, pos):
        if 2*pos+1 >= self.size: return
        if 2*pos+2 >= self.size or self.inList.get(2*pos+1) > self.inList.get(2*pos+2):
            maxChild = 2*pos+1
        else: maxChild = 2*pos+2
        if self.inList.get(maxChild) < self.inList.get(pos): return
        self.inList.swap(pos,maxChild)
        self.heapify(maxChild)
        
    def removeRoot(self):
        val = self.inList.get(0)
        self.inList.set(0,self.inList.get(self.size-1))
        self.inList.remove(self.size-1)
        self.size -= 1
        self.heapify(0)
        return val
    
    def append(self, d):
        self.inList.append(d)
        self.size += 1
    
    #question 2a
    def max(self):
        #returns the top element of the heap.
        return self.inList.get(0)
    
    #question 2b
    def getRelative(self, pos, flag):
        if flag == 0: #return parent 
            return self.inList.get((pos-1)//2)
        elif flag == 1: #return left child 
            return self.inList.get(2*pos+1)
        else: #return right child
            return self.inList.get(2*pos+2)
        
    #question 2c
    def sumAll(self):
        total = 0
        for i in range(self.inList.length()):
            total += self.inList.get(i)
        return total
    
    #question 3
    def min(self):
        smallest = self.inList.get(0)
        i=0
        while self.inList.get(i) != 0:
            if self.inList.get(i) < smallest:
                smallest = self.inList.get(i)            
            i += 1
        return smallest
    
    #question 4
    def removeVal(self,d):
        for i in range(self.inList.length()):
            if self.inList.get(i) == d:
                self.inList.set(0,self.inList.get(self.size-1))
                self.inList.remove(self.size-1)
                self.size -= 1
                self.heapify(i)
                return i                
        return 
    
    
                
            
           
                
        
            
            
        
        
h = Heap()
h.add(4); h.add(42); h.add(0); h.add(-4); h.add(124); h.add(0); h.add(34); h.add(0); h.add(43)
print(h)
print(h.removeRoot(),h)
print(h.removeRoot(),h)
print(h.removeRoot(),h)

#question 2a testing
print(h.max())

#questoin 2b testing
print(h.getRelative(1,1))

#question 2c testing
print(h.sumAll())

#question 3 testing
print(h.min())

#question 4 testing
print(h.removeVal(-4))



def heapSort1(A):
    h = Heap()
    for i in range(len(A)):
        h.add(A[i])
    for i in range(len(A)-1,-1,-1):
        A[i] = h.removeRoot()
        
# A = [34,1,6,56,1,-3,124,54,12,7,23,9,-23]
# heapSort1(A)
# print(A)

# def heapSort2(A):
#     h = Heap()
#     for i in range(len(A)):
#         h.append(A[i])
#     for i in range(len(A)-1,-1,-1):
#         h.heapify(i)
#     for i in range(len(A)-1,-1,-1):
#         A[i] = h.removeRoot()
        
# A = [34,1,6,56,1,-3,124,54,12,7,23,9,-23]
# heapSort2(A)
# print(A)


def heapify(A, n, i):
    largest = i
    left = 2*i+1
    right = 2*i+2
    if left < n and A[largest] < A[left]:
        largest = left
    if right < n and A[largest] < A[right]:
        largest = right
    if largest != i:
        A[i], A[largest] = A[largest], A[i]
        heapify(A, n, largest)

#question 5
def heapSort3(A):
    h = Heap()
    for i in range(len(A)//2-1,-1,-1):
        heapify(A,len(A),i)
    for i in range(len(A)-1,0-1):
        temp = A[i]
        A[i]=A[0]
        A[0] = temp
        heapify(A,i,0)

A = [34,1,6,56,1,-3,124,54,12,7,23,9,-23]
print(A)
heapSort3(A)
print(A)

#question 6
class PQElement:
    def __init__(self, v, p):
        self.val = v
        self.priority = p
        
    def __str__(self):
        return "("+str(self.val)+","+str(self.priority)+")"
        
class PQueue:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0        
        
    def size(self):
        return self.count
        
    def enq(self, d):
        self.append(d)
        #tmp = [0 for i in range(10)]        
        #for i in range(self.size()-1,0,-1):
            #tmp[i] = self.inArray[i]
        #self.inArray=tmp
            
    def deq(self):
        x = 0
        for i in range(self.size()):
            if self.inArray[x].priority < self.inArray[i].priority:
                x = i
        self.remove(x)
        return self.inArray[x]
    
    def __str__(self):
        array = "["
        for i in range(self.size()):
            array = array + str(self.get(i)) 
        array = array + "]"
        return array           
        
    def append(self, e):
        self.inArray[self.count] = e
        tmp = [0 for i in range(10)]       
        if self.count > 0:
            if self.inArray[self.count].priority < self.inArray[self.count-1].priority:
                tmp = self.inArray[self.count]
                self.inArray[self.count] = self.inArray[self.count-1]
                self.inArray[self.count-1] = tmp                
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()     # resize array if reached capacity
    
           
    
    def remove(self, i):
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val 
    
    def get(self, i):
        return self.inArray[i]

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
        
#question 5 testing
pq = PQueue()
for i in range(10):
    (x,y) = (i**2%10,i**2%50); print((x,y), end=" ")
    pq.enq(PQElement(x,y))
print("\nPQueue: "+str(pq)); pq.deq(); print("After deq: "+str(pq))
# Out:
# [124, 43, 34, 42, 4, 0, 0, -4, 0]
# 124 [43, 42, 34, 0, 4, 0, 0, -4]
# 43 [42, 4, 34, 0, -4, 0, 0]
# 42 [34, 4, 0, 0, -4, 0]
# 34
# 0
# 34
# 4
# 4
# [34, 1, 6, 56, 1, -3, 124, 54, 12, 7, 23, 9, -23]
# [124, 56, 34, 54, 23, 9, 6, 1, 12, 7, 1, -3, -23]
# (0, 0) (1, 1) (4, 4) (9, 9) (6, 16) (5, 25) (6, 36) (9, 49) (4, 14) (1, 31)
# PQueue: [(0,0)(1,1)(4,4)(9,9)(6,16)(5,25)(6,36)(4,14)(1,31)(9,49)]
# After deq: [(0,0)(1,1)(4,4)(9,9)(6,16)(5,25)(6,36)(4,14)(1,31)]

# %%
class ArrayList:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
        
    def swap(self, i, j):
        tmp = self.inArray[i]
        self.inArray[i] = self.inArray[j]
        self.inArray[j] = tmp
    
    def get(self, i):
        return self.inArray[i]

    def set(self, i, e):
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()     # resize array if reached capacity

    def insert(self, i, e):
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()     # resize array if reached capacity

    def remove(self, i):
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val
    
    def __str__(self):
        return str(self.inArray[:self.count])

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray


# some testing
a = ArrayList()
for i in range(9): a.append(i)
print(a.inArray, a.count)
a.append(9)
print(a.inArray, a.count)
a.set(2,24)
print(a.inArray, a.count)
print(a.get(0), a.length())
a.insert(4,42)
print(a.inArray, a.count)
print(a.remove(4), a.inArray, a.count)
print(a.inArray, a.count)
print(a)
